# %% [markdown]
# ## Чёт запускаем на хелиосе

# %%
# !cat lab0.sh | ssh -p 2222 s367349@se.ifmo.ru bash
# Out:
# Starting...
# Creating files n' dirs...
# Filling files...
# Giving permissions...
# Throwing files n' links around...
# cp: exploud3: Permission denied
# cat: gligar8/magby/machamp: Permission denied
# cat: gligar8/magby/machamp: Permission denied
# cp: exploud3: Permission denied
# cp: honchkrow9: Permission denied
# ln: gligar8/magby/vulpix/haxoruslarvitar: Permission denied
# cp: gligar8/magby/vulpix/gligar8: Permission denied
# ln: gligar8/magby/vulpix/espeonlarvitar: Permission denied
# ln: arbok3/dwebble/larvitarlarvitar: File exists
# cp: arbok3/serperiorexploud: Permission denied
# Doing county things...
# - here it goes 1
# - here it goes 2
# cp: arbok3/dwebble: Permission denied
# cp: arbok3/simisage: Permission denied
# ls: honchkrow9/**: No such file or directory
# -r--r-----  2 s367349  studs   36 31 окт.  07:42 jellicent2
# -rw-r--r--  1 s367349  studs   91 31 окт.  07:42 jellicent2_31
# -rw--w----  1 s367349  studs   20 31 окт.  07:42 larvitar1
# ...

# %% [markdown]
# ## Зачистка нанесённого ущерба

# %%
# !ssh -p 2222 s367349@se.ifmo.ru 'chmod -R 700 lab0 && rm -r lab0'
